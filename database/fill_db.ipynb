# %%
import pandas as pd
import os
import psycopg2 
from urllib.parse import urlparse
from dotenv import load_dotenv
from uuid import NAMESPACE_URL, uuid5
import requests

# %%
load_dotenv()
DATABASE_URL = os.getenv("DATABASE_URL")
result = urlparse(DATABASE_URL)
username = result.username
password = result.password
database = result.path[1:]
hostname = result.hostname
port = result.port

# %%
connection = psycopg2.connect(
    database = database,
    user = username,
    password = password,
    host = hostname,
    port = port
)

# %%
cols = ['id', 'Program Full Name', 'Program', 'Description',  'URL', 'logo link']

# %%
dcc_df = pd.read_csv("data/DCC.tsv", sep="\t")
dcc_df.id = ""
for i,row in dcc_df.iterrows():
    dcc_df.at[i, "id"] = uuid5(NAMESPACE_URL, row["Program"])
    extension = dcc_df.at[i, "logo link"].split("/")[-1].split(".")[-1]
    r = requests.get(dcc_df.at[i, "logo link"], allow_redirects=True)
    open("../drc-portals/public/img/%s.%s"%(row["Program"], extension), 'wb').write(r.content)
    dcc_df.at[i, "logo link"] = "img/%s.%s"%(row["Program"], extension)
dcc_df = dcc_df[cols]
dcc_df.to_csv('output/DCC.tsv', sep="\t", header=False, index=False)
dcc_df.head()
# Out:
# /var/folders/wq/7bkxhy8j7ql194c1fbby4gy40000gn/T/ipykernel_82223/1889984218.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'd6bb00c3-7224-5001-b9c5-9838622fba40' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dcc_df.at[i, "id"] = uuid5(NAMESPACE_URL, row["Program"])
#                                      id  \
# 0  d6bb00c3-7224-5001-b9c5-9838622fba40
# 1  f65babf7-2875-5725-9635-210d654533f1
# 2  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 3  b3028db2-209c-5862-8f4d-33c5b312332e
# 4  803ad44d-e7a2-550a-95c6-57855bf06be8
#
#                                 Program Full Name     Program  \
# 0                                     4D Nucleome         4DN
# 1                 Extracellular RNA Communication       ExRNA
# 2  Gabriella Miller Kids First Pediatric Research  Kids First
# 3                      Genotype Tissue Expression        GTEx
# 4                Human BioMolecular Atlas Program      HuBMAP
#
#                                          Description  \
# 0  The Common Fund’s 4D Nucleome program aims to ...
# 1  The Extracellular RNA Communication program is...
# 2  The goal of the Gabriella Miller Kids First Pe...
# 3  The Genotype-Tissue Expression (GTEx) project ...
# 4  The goal of the Human BioMolecular Atlas Progr...
#
#                                 URL           logo link
# 0       https://www.4dnucleome.org/         img/4DN.png
# 1                https://exrna.org/       img/ExRNA.png
# 2         https://kidsfirstdrc.org/  img/Kids First.png
# 3  https://www.gtexportal.org/home/        img/GTEx.png
# 4     https://hubmapconsortium.org/      img/HuBMAP.png

# %%
cur = connection.cursor()
cur.execute('''
  create table dcc_tmp
  as table dccs
  with no data;
''')

with open('output/DCC.tsv', 'r') as fr:
    cur.copy_from(fr, 'dcc_tmp',
      columns=('id', 'label', 'short_label', 'description', 'homepage', 'icon'),
      null='',
      sep='\t',
    )

# %%
cur.execute('''
    insert into dccs (id, label, short_label, description, homepage, icon)
      select id, label, short_label, description, homepage, icon
      from dcc_tmp
      on conflict (id)
        do update
        set label = excluded.label,
            short_label = excluded.short_label,
            description = excluded.description,
            homepage = excluded.homepage,
            icon = excluded.icon
    ;
  ''')
cur.execute('drop table dcc_tmp;')
connection.commit()

# %%
cur.close()

# %%
dcc_mapper = {
    'KF': '65af85ae-82d5-5b81-bc66-6bddaa6420ce',
    'GTEx': 'b3028db2-209c-5862-8f4d-33c5b312332e',
    'HuBMAP': '803ad44d-e7a2-550a-95c6-57855bf06be8',
    'IDG': 'a1289ebb-0306-59a1-b0fc-e4d03a4790d7',
    'LINCS': 'f3f490cf-fd69-579c-8ea3-472c7cf3fb59',
    'Metabolomics': '089d8d63-3364-526f-9706-80d62d0ec88c',
    'SPARC': '2399794e-74c6-5735-a039-0782cdeeb1e2',
}

# %%
publications_df = pd.read_csv("data/publications.tsv", sep="\t")
cols = ["id", "Title", "Year", "Page", "Volume", "Issue", "Journal", "pmid", "PMCID", "DOI", "Authors"]
publications_df.id = ""
for i, row in publications_df.iterrows():
    publications_df.at[i, "id"] = uuid5(NAMESPACE_URL, row["Title"])
    publications_df.at[i, "program"] = dcc_mapper[publications_df.at[i, "program"]]
publications_df[cols].groupby('id').first().to_csv("output/publications.tsv", sep="\t", header=False)
publications_df[cols].head()
# Out:
#                                      id  \
# 0  b2edba84-bdd1-5f3f-855f-8a45e88d98cf
# 1  b3b12752-8f5c-5e5e-8dd0-e46afbc83b4a
# 2  aca50121-fcde-5541-9277-8adf75152db6
# 3  2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4  7d2732f5-4a7e-5b28-a096-7db93ad1946b
#
#                                                Title  Year      Page  Volume  \
# 0  Toxicology knowledge graph for structural birt...  2023        98       3
# 1  Pan-African genome demonstrates how population...  2022      4384      13
# 2  RNAget: an API to securely retrieve RNA quanti...  2023       NaN      39
# 3  3D virtual reality vs. 2D desktop registration...  2021  e0258103      16
# 4  Tissue registration and exploration user inter...  2022      1369       5
#
#   Issue                           Journal      pmid        PMCID  \
# 0     1           Communications medicine  37460679  PMC10352311
# 1     1             Nature communications  35927245   PMC9352875
# 2     4  Bioinformatics (Oxford, England)  36897015  PMC10081869
# 3    10                          PloS one  34705835   PMC8550408
# 4     1            Communications biology  36513738   PMC9747802
#
#                               DOI  \
# 0      10.1038/s43856-023-00329-2
# 1      10.1038/s41467-022-31724-3
# 2  10.1093/bioinformatics/btad126
# 3    10.1371/journal.pone.0258103
# 4      10.1038/s42003-022-03644-x
#
#                                              Authors
# 0  Evangelista JE, Clarke DJB, Xie Z, Marino GB, ...
# 1  Tetikol HS, Turgut D, Narci K, Budak G, Kalay ...
# 2  Upchurch S, Palumbo E, Adams J, Bujold D, Bour...
# 3           Bueckle A, Buehling K, Shih PC, Borner K
# 4  Borner K, Bueckle A, Herr BW 2nd, Cross LE, Qu...

# %%
publications_df[["id", "program"]].to_csv("output/dcc_publications.tsv", sep="\t", header=False, index=False)

# %%
cur = connection.cursor()
cur.execute('''
  create table publication_tmp
  as table publications
  with no data;
''')

with open('output/publications.tsv', 'r') as fr:
    cur.copy_from(fr, 'publication_tmp',
      columns=("id", "title", "year", "page", "volume", "issue", "journal", "pmid", "pmcid", "doi", "authors"),
      null='',
      sep='\t',
    )

# %%
cur.execute('''
    insert into publications (id, title, year, page, volume, issue, journal, pmid, pmcid, doi, authors)
      select id, title, year, page, volume, issue, journal, pmid, pmcid, doi, authors
      from publication_tmp
      on conflict (id)
        do update
        set id = excluded.id,
            title = excluded.title,
            year = excluded.year,
            page = excluded.page,
            volume = excluded.volume,
            issue = excluded.issue,
            journal = excluded.journal,
            pmid = excluded.pmid,
            pmcid = excluded.pmcid,
            doi = excluded.doi,
            authors = excluded.authors
    ;
  ''')
cur.execute('drop table publication_tmp;')
connection.commit()

# %%
cur.close()

# %%
publications_df = pd.read_csv("data/publications.tsv", sep="\t")
publications_df.head()
# Out:
#   program  coreproject AwardType  \
# 0      KF  OT2OD030162      CFDE
# 1      KF  OT2OD030162      CFDE
# 2    GTEx  OT2OD030161      CFDE
# 3  HuBMAP  OT2OD030545      CFDE
# 4  HuBMAP  OT2OD030545      CFDE
#
#                                                Title  Year      Page  Volume  \
# 0  Toxicology knowledge graph for structural birt...  2023        98       3
# 1  Pan-African genome demonstrates how population...  2022      4384      13
# 2  RNAget: an API to securely retrieve RNA quanti...  2023       NaN      39
# 3  3D virtual reality vs. 2D desktop registration...  2021  e0258103      16
# 4  Tissue registration and exploration user inter...  2022      1369       5
#
#   Issue                           Journal      pmid        PMCID  \
# 0     1           Communications medicine  37460679  PMC10352311
# 1     1             Nature communications  35927245   PMC9352875
# 2     4  Bioinformatics (Oxford, England)  36897015  PMC10081869
# 3    10                          PloS one  34705835   PMC8550408
# 4     1            Communications biology  36513738   PMC9747802
#
#                               DOI  \
# 0      10.1038/s43856-023-00329-2
# 1      10.1038/s41467-022-31724-3
# 2  10.1093/bioinformatics/btad126
# 3    10.1371/journal.pone.0258103
# 4      10.1038/s42003-022-03644-x
#
#                                              Authors
# 0  Evangelista JE, Clarke DJB, Xie Z, Marino GB, ...
# 1  Tetikol HS, Turgut D, Narci K, Budak G, Kalay ...
# 2  Upchurch S, Palumbo E, Adams J, Bujold D, Bour...
# 3           Bueckle A, Buehling K, Shih PC, Borner K
# 4  Borner K, Bueckle A, Herr BW 2nd, Cross LE, Qu...

# %%
cur = connection.cursor()
cur.execute('''
  create table dcc_publication_tmp
  as table dcc_publications
  with no data;
''')

with open('output/dcc_publications.tsv', 'r') as fr:
    cur.copy_from(fr, 'dcc_publication_tmp',
      columns=("publication_id", "dcc_id"),
      null='',
      sep='\t',
    )

# %%
cur.execute('''
    insert into dcc_publications (publication_id, dcc_id)
      select publication_id, dcc_id
      from dcc_publication_tmp
      on conflict 
        do nothing
    ;
  ''')
cur.execute('drop table dcc_publication_tmp;')
connection.commit()

# %%
cur.close()
connection.close()

# %%
import json

# %%
dcc = pd.read_csv('ingest/DCC.tsv', sep="\t", header=None)
mapper = {}
for k,v in dcc.iterrows():
    mapper[v[2]] = v[0]
mapper
# Out:
# {'4DN': 'd6bb00c3-7224-5001-b9c5-9838622fba40',
#  'ExRNA': 'f65babf7-2875-5725-9635-210d654533f1',
#  'Kids First': '65af85ae-82d5-5b81-bc66-6bddaa6420ce',
#  'GTEx': 'b3028db2-209c-5862-8f4d-33c5b312332e',
#  'HuBMAP': '803ad44d-e7a2-550a-95c6-57855bf06be8',
#  'IDG': 'a1289ebb-0306-59a1-b0fc-e4d03a4790d7',
#  'LINCS': 'f3f490cf-fd69-579c-8ea3-472c7cf3fb59',
#  'Metabolomics': '089d8d63-3364-526f-9706-80d62d0ec88c',
#  'MoTrPAC': 'a9aeab22-4fbc-5329-aef6-21110f463c23',
#  'SPARC': '2399794e-74c6-5735-a039-0782cdeeb1e2',
#  'HMP': 'cbfd44b8-684d-56b9-bfd4-45c0e259f896',
#  'Glycoscience': 'e31052b0-ac50-5ede-9828-698ff3610427',
#  'UDN': '7be6ce16-142e-508e-a31f-108e70ce72c2',
#  'KOMP2': '830ddbac-bf21-5612-af1a-75c713045299',
#  'A2CPS': 'e332dadd-8084-5fbc-be41-29d75775aab3',
#  'SenNet': 'dd66e8a5-0e05-5a43-a0ca-18cc3698bb36',
#  'Bridge2AI': '75b3be39-a021-5d80-b7e2-2a7938a1e11a',
#  'iHMP': 'dafdfc72-42c6-5c35-ad56-0b2d284431d1',
#  'H3Africa': '138b48df-8867-5d61-87c5-98cf924c60b9'}

# %%
outreach = pd.read_csv('data/outreach.tsv', sep="\t")
outreach.id = ""
outreach["active"] = True

for k,v in outreach.iterrows():
    outreach.at[k,"id"] = str(uuid5(NAMESPACE_URL, v["title"]))
    outreach.at[k, "dcc"] = mapper[v["dcc"]]
    outreach.at[k, "tag"] = json.dumps([v["tag"]])
outreach
# Out:
# /var/folders/wq/7bkxhy8j7ql194c1fbby4gy40000gn/T/ipykernel_63850/1651161684.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '64647877-fecd-5514-bdda-dcdbbe6fa4ba' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   outreach.at[k,"id"] = str(uuid5(NAMESPACE_URL, v["title"]))
#                                                title  \
# 0  2024 HuBMAP Underrepresented Student Internshi...
# 1  Summer Research Program in Biomedical Big Data...
# 2  Coursera Course: Big Data Science with the BD2...
# 3  SenNet + HOA - Hacking the Human Vasculature i...
# 4                 GlyGen & CFDE Workshop Summer 2023
# 5                HuBMAP Visible Human MOOC (VHMOOC)
#
#                                    short_description  \
# 0  The Underrepresented Student Internship Progra...
# 1  LINCS’ Summer Research Training Program in Bio...
# 2  In this course the LINCS DCC covers computatio...
# 3  The goal of this competition is to segment blo...
# 4   This workshop provides an opportunity to lear...
# 5  This 10h course introduces the HuBMAP project ...
#
#                                          description                     tag  \
# 0  Applications will be accepted from November 27...          ["internship"]
# 1  LINCS’ Summer Research Training Program in Bio...          ["internship"]
# 2  In this course the LINCS DCC introduces the da...       ["online course"]
# 3  The “SenNet + HOA - Hacking the Human Vasculat...  ["online competition"]
# 4  The purpose of this workshop is to bring toget...            ["workshop"]
# 5  This 10h course introduces the HuBMAP project ...       ["online course"]
#
#    featured  start_date    end_date  start_time  end_time  \
# 0      True  05/20/2024  08/16/2024         NaN       NaN
# 1     False  06/03/2024  08/09/2024         NaN       NaN
# 2     False         NaN         NaN         NaN       NaN
# 3     False  11/07/2023  02/06/2024         NaN       NaN
# 4      True  08/07/2023         NaN         NaN       NaN
# 5     False         NaN         NaN         NaN       NaN
#
#                                                 link  \
# 0   https://hubmapconsortium.org/internship-program/
# 1  https://labs.icahn.mssm.edu/maayanlab/summer-r...
# 2          https://www.coursera.org/learn/bd2k-lincs
# 3  https://www.kaggle.com/competitions/blood-vess...
# 4  https://wiki.glygen.org/GlyGen_CFDE_Workshop_S...
# 5  https://expand.iu.edu/browse/sice/cns/courses/...
#
#                                 image                                   dcc  \
# 0          /img/hubmap_internship.png  803ad44d-e7a2-550a-95c6-57855bf06be8
# 1           /img/lincs_internship.png  f3f490cf-fd69-579c-8ea3-472c7cf3fb59
# 2             /img/lincs_coursera.png  f3f490cf-fd69-579c-8ea3-472c7cf3fb59
# 3  /img/blood-vessel-segmentation.png  dd66e8a5-0e05-5a43-a0ca-18cc3698bb36
# 4       /img/glygen-2023-workshop.png  e31052b0-ac50-5ede-9828-698ff3610427
# 5                /img/hubmap_mooc.png  803ad44d-e7a2-550a-95c6-57855bf06be8
#
#    active                                    id
# 0    True  64647877-fecd-5514-bdda-dcdbbe6fa4ba
# 1    True  2adfed62-834f-5984-bd23-2f1029dda967
# 2    True  914748db-5159-5fde-96a6-a966bdfa70b6
# 3    True  bf9a64ab-51a9-566a-8f27-1bd2694ab18b
# 4    True  cda5c73a-3bcb-55e5-80bf-d91d3f220bbf
# 5    True  79cf307e-bad9-5594-9c2c-a07a6453b5a0

# %%
cols = ['title', 'short_description', 'description', 'tag', 'featured',
       'start_date', 'end_date', 'start_time', 'end_time', 'link', 'image',
       'dcc', 'id', 'active']
outreach[['id', 'title', 'short_description', 'description', 'tag', 'featured','active',
       'start_date', 'end_date', 'start_time', 'end_time', 'link', 'image']].to_csv("output/outreach.tsv", sep="\t", header=None, index=None)

# %%
outreach[["id", "dcc"]].to_csv("output/dcc_outreach.tsv", sep="\t", header=None, index=None)

# %%
outreach[["id", "dcc"]]
# Out:
#                                      id                                   dcc
# 0  64647877-fecd-5514-bdda-dcdbbe6fa4ba  803ad44d-e7a2-550a-95c6-57855bf06be8
# 1  2adfed62-834f-5984-bd23-2f1029dda967  f3f490cf-fd69-579c-8ea3-472c7cf3fb59
# 2  914748db-5159-5fde-96a6-a966bdfa70b6  f3f490cf-fd69-579c-8ea3-472c7cf3fb59
# 3  bf9a64ab-51a9-566a-8f27-1bd2694ab18b  dd66e8a5-0e05-5a43-a0ca-18cc3698bb36
# 4  cda5c73a-3bcb-55e5-80bf-d91d3f220bbf  e31052b0-ac50-5ede-9828-698ff3610427
# 5  79cf307e-bad9-5594-9c2c-a07a6453b5a0  803ad44d-e7a2-550a-95c6-57855bf06be8

# %%
import boto3
from botocore.exceptions import ClientError
from glob import glob

# %%
def upload_file(file_name, bucket, object_name=None):
    """Upload a file to an S3 bucket

    :param file_name: File to upload
    :param bucket: Bucket to upload to
    :param object_name: S3 object name. If not specified then file_name is used
    :return: True if file was uploaded, else False
    """

    # If S3 object_name was not specified, use file_name
    if object_name is None:
        object_name = os.path.basename(file_name)

    # Upload the file
    s3_client = boto3.client('s3')
    try:
        response = s3_client.upload_file(file_name, bucket, object_name)
    except ClientError as e:
        print(e)
        return False
    return True

# %%
bucket = 'cfde-drc'

# %%
for f in glob("output/*"):
    filename = f.replace('output', 'database/110723')
    print(filename)
    upload_file(f,bucket, filename)
# Out:
# database/110723/DCC.tsv
# database/110723/dcc_outreach.tsv
# database/110723/dcc_publications.tsv
# database/110723/outreach.tsv
# database/110723/publications.tsv

# %% [markdown]
# ## Database Ingestion
#
# You can run this part to ingest the db entries. Make sure you download the contents of cfde-drc/database/<current date> and put it in ingest/ folder

# %%
import pandas as pd
import os
import psycopg2
import pathlib
from urllib.parse import urlparse
from dotenv import load_dotenv
from uuid import NAMESPACE_URL, uuid5

# %%
# load .env from drc-portals potentially
load_dotenv('../drc-portals/.env')
load_dotenv()
DATABASE_URL = os.getenv("DATABASE_URL")
result = urlparse(DATABASE_URL)
username = result.username
password = result.password
database = result.path[1:]
hostname = result.hostname
port = result.port

# %%
connection = psycopg2.connect(
    database = database,
    user = username,
    password = password,
    host = hostname,
    port = port
)

# %%
# Fetch data for ingest
if not pathlib.Path('ingest').exists():
  pathlib.Path('ingest').mkdir()
if not pathlib.Path('ingest/DCC.tsv').exists():
  import urllib.request
  urllib.request.urlretrieve('https://cfde-drc.s3.amazonaws.com/database/110723/DCC.tsv', 'ingest/DCC.tsv')
if not pathlib.Path('ingest/dcc_publications.tsv').exists():
  import urllib.request
  urllib.request.urlretrieve('https://cfde-drc.s3.amazonaws.com/database/110723/dcc_publications.tsv', 'ingest/dcc_publications.tsv')
if not pathlib.Path('ingest/publications.tsv').exists():
  import urllib.request
  urllib.request.urlretrieve('https://cfde-drc.s3.amazonaws.com/database/110723/publications.tsv', 'ingest/publications.tsv')

# %%
cur = connection.cursor()
cur.execute('''
  create table dcc_tmp
  as table dccs
  with no data;
''')

with open('ingest/DCC.tsv', 'r') as fr:
    cur.copy_from(fr, 'dcc_tmp',
      columns=('id', 'label', 'short_label', 'description', 'homepage', 'icon'),
      null='',
      sep='\t',
    )

# %%
cur.execute('''
    insert into dccs (id, label, short_label, description, homepage, icon)
      select id, label, short_label, description, homepage, icon
      from dcc_tmp
      on conflict (id)
        do update
        set label = excluded.label,
            short_label = excluded.short_label,
            description = excluded.description,
            homepage = excluded.homepage,
            icon = excluded.icon
    ;
  ''')
cur.execute('drop table dcc_tmp;')
connection.commit()

# %%
cur = connection.cursor()
cur.execute('''
  create table publication_tmp
  as table publications
  with no data;
''')

with open('ingest/publications.tsv', 'r') as fr:
    cur.copy_from(fr, 'publication_tmp',
      columns=("id", "title", "year", "page", "volume", "issue", "journal", "pmid", "pmcid", "doi", "authors"),
      null='',
      sep='\t',
    )

# %%
cur.execute('''
    insert into publications (id, title, year, page, volume, issue, journal, pmid, pmcid, doi, authors)
      select id, title, year, page, volume, issue, journal, pmid, pmcid, doi, authors
      from publication_tmp
      on conflict (id)
        do update
        set id = excluded.id,
            title = excluded.title,
            year = excluded.year,
            page = excluded.page,
            volume = excluded.volume,
            issue = excluded.issue,
            journal = excluded.journal,
            pmid = excluded.pmid,
            pmcid = excluded.pmcid,
            doi = excluded.doi,
            authors = excluded.authors
    ;
  ''')
cur.execute('drop table publication_tmp;')
connection.commit()

# %%
cur = connection.cursor()
cur.execute('''
  create table dcc_publication_tmp
  as table dcc_publications
  with no data;
''')

with open('ingest/dcc_publications.tsv', 'r') as fr:
    cur.copy_from(fr, 'dcc_publication_tmp',
      columns=("publication_id", "dcc_id"),
      null='',
      sep='\t',
    )

# %%
cur.execute('''
    insert into dcc_publications (publication_id, dcc_id)
      select publication_id, dcc_id
      from dcc_publication_tmp
      on conflict 
        do nothing
    ;
  ''')
cur.execute('drop table dcc_publication_tmp;')
connection.commit()

cur.close()
connection.close()

# %%
program = "Human Heredity & Health in Africa"
uuid5(NAMESPACE_URL, program)
# Out:
# UUID('138b48df-8867-5d61-87c5-98cf924c60b9')

# %%
import pandas as pd

# %%
outreach = pd.read_csv("output/outreach.tsv", sep="\t", header=None)
outreach
# Out:
#                                      0   \
# 0  64647877-fecd-5514-bdda-dcdbbe6fa4ba
# 1  2adfed62-834f-5984-bd23-2f1029dda967
# 2  914748db-5159-5fde-96a6-a966bdfa70b6
# 3  bf9a64ab-51a9-566a-8f27-1bd2694ab18b
# 4  cda5c73a-3bcb-55e5-80bf-d91d3f220bbf
# 5  79cf307e-bad9-5594-9c2c-a07a6453b5a0
#
#                                                   1   \
# 0  2024 HuBMAP Underrepresented Student Internshi...
# 1  Summer Research Program in Biomedical Big Data...
# 2  Coursera Course: Big Data Science with the BD2...
# 3  SenNet + HOA - Hacking the Human Vasculature i...
# 4                 GlyGen & CFDE Workshop Summer 2023
# 5                HuBMAP Visible Human MOOC (VHMOOC)
#
#                                                   2   \
# 0  The Underrepresented Student Internship Progra...
# 1  LINCS’ Summer Research Training Program in Bio...
# 2  In this course the LINCS DCC covers computatio...
# 3  The goal of this competition is to segment blo...
# 4   This workshop provides an opportunity to lear...
# 5  This 10h course introduces the HuBMAP project ...
#
#                                                   3                       4   \
# 0  Applications will be accepted from November 27...          ["internship"]
# 1  LINCS’ Summer Research Training Program in Bio...          ["internship"]
# 2  In this course the LINCS DCC introduces the da...       ["online course"]
# 3  The “SenNet + HOA - Hacking the Human Vasculat...  ["online competition"]
# 4  The purpose of this workshop is to bring toget...            ["workshop"]
# 5  This 10h course introduces the HuBMAP project ...       ["online course"]
#
#       5     6           7           8           9           10  \
# 0   True  True  05/20/2024  08/16/2024  11/07/2023  02/01/2024
# 1  False  True  06/03/2024  08/09/2024         NaN  02/01/2024
# 2  False  True         NaN         NaN         NaN         NaN
# 3  False  True  11/07/2023  02/06/2024         NaN  01/30/2024
# 4   True  True  08/07/2023         NaN         NaN         NaN
# 5  False  True         NaN         NaN         NaN         NaN
#
#                                                   11  \
# 0   https://hubmapconsortium.org/internship-program/
# 1  https://labs.icahn.mssm.edu/maayanlab/summer-r...
# 2          https://www.coursera.org/learn/bd2k-lincs
# 3  https://www.kaggle.com/competitions/blood-vess...
# 4  https://wiki.glygen.org/GlyGen_CFDE_Workshop_S...
# 5  https://expand.iu.edu/browse/sice/cns/courses/...
#
#                                    12
# 0          /img/hubmap_internship.png
# 1           /img/lincs_internship.png
# 2             /img/lincs_coursera.png
# 3  /img/blood-vessel-segmentation.png
# 4       /img/glygen-2023-workshop.png
# 5                /img/hubmap_mooc.png

# %%
outreach[7] = pd.to_datetime(outreach[7]).apply(lambda dt: dt.tz_localize(tz='America/New_York').isoformat())
outreach[8] = pd.to_datetime(outreach[8]).apply(lambda dt: dt.tz_localize(tz='America/New_York').isoformat())
outreach[9] = pd.to_datetime(outreach[9]).apply(lambda dt: dt.tz_localize(tz='America/New_York').isoformat())
outreach[10] = pd.to_datetime(outreach[10]).apply(lambda dt: dt.tz_localize(tz='America/New_York').isoformat())

# %%
outreach.to_csv("output/outreach.tsv", header=None, sep="\t")

# %%
landmark = pd.read_csv("data/landmark_publications.tsv", sep="\t")
landmark.head()
# Out:
#      DCC                                              Title  \
# 0    4DN                            The 4D nucleome project
# 1    4DN  Elucidating the structure and function of the ...
# 2  ExRNA  The NIH Extracellular RNA Communication Consor...
# 3   GTEx      The Genotype-Tissue Expression (GTEx) project
# 4   GTEx  Human genomics. The Genotype-Tissue Expression...
#
#                              Journal  Year      pmid  \
# 0                             Nature  2017  28905911
# 1                     Molecular Cell  2023  36640770
# 2  Journal of Extracellular Vesicles  2015  26320938
# 3                    Nature Genetics  2013  23715323
# 4                            Science  2015  25954001
#
#                             doi  \
# 0           10.1038/nature23884
# 1  10.1016/j.molcel.2022.12.025
# 2          10.3402/jev.v4.27493
# 3               10.1038/ng.2653
# 4       10.1126/science.1262110
#
#                                             citation
# 0  Dekker J, Belmont AS, Guttman M, Leshyk VO, Li...
# 1  Roy AL, Conroy RS, Taylor VG, Mietz J, Fingerm...
# 2  Ainsztein AM, Brooks PJ, Dugan VG, Ganguly A, ...
# 3  GTEx Consortium. The Genotype-Tissue Expressio...
# 4  GTEx Consortium. Human genomics. The Genotype-...

# %%
pub_cols = ["id", "title", "year", "page", "volume", "issue", "journal", "pmid", "pmcid", "doi", "authors", "landmark"]
dcc_pub_cols = ["publication_id", "dcc_id"]

# %%
publications = pd.read_csv('output/publications.tsv', sep="\t", header=None)
publications["landmark"] = False
publications.columns = pub_cols
publications = publications.set_index("id")
publications.head()
# Out:
#                                                                                   title  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  3D virtual reality vs. 2D desktop registration...
# 27147bd8-9969-5750-a964-698000f6944a  Computational screen to identify potential tar...
# 29ddbfb6-4131-5874-ba94-75b664fc8335  Contribution of Circulating Host and Microbial...
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  Lactate-dependent transcriptional regulation c...
# 33d76b34-d7db-505e-a551-233d36740154  Modular and mechanistic changes across stages ...
#
#                                       year               page  volume issue  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  2021           e0258103      16    10
# 27147bd8-9969-5750-a964-698000f6944a  2023             e13809      22     6
# 29ddbfb6-4131-5874-ba94-75b664fc8335  2023  11786469231182510      16   NaN
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  2023               4129      14     1
# 33d76b34-d7db-505e-a551-233d36740154  2022                436      22     1
#
#                                                                                 journal  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce                                           PloS one
# 27147bd8-9969-5750-a964-698000f6944a                                         Aging cell
# 29ddbfb6-4131-5874-ba94-75b664fc8335  International journal of tryptophan research :...
# 3370a33a-d28e-5027-a3a0-e8489a4259ad                              Nature communications
# 33d76b34-d7db-505e-a551-233d36740154                                         BMC cancer
#
#                                           pmid        pmcid  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  34705835   PMC8550408
# 27147bd8-9969-5750-a964-698000f6944a  37082798  PMC10265163
# 29ddbfb6-4131-5874-ba94-75b664fc8335  37441265  PMC10334013
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  37452018  PMC10349100
# 33d76b34-d7db-505e-a551-233d36740154  35448980   PMC9022252
#
#                                                                doi  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  10.1371/journal.pone.0258103
# 27147bd8-9969-5750-a964-698000f6944a            10.1111/acel.13809
# 29ddbfb6-4131-5874-ba94-75b664fc8335     10.1177/11786469231182510
# 3370a33a-d28e-5027-a3a0-e8489a4259ad    10.1038/s41467-023-39672-2
# 33d76b34-d7db-505e-a551-233d36740154    10.1186/s12885-022-09479-3
#
#                                                                                 authors  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce           Bueckle A, Buehling K, Shih PC, Borner K
# 27147bd8-9969-5750-a964-698000f6944a  Deng EZ, Fleishman RH, Xie Z, Marino GB, Clark...
# 29ddbfb6-4131-5874-ba94-75b664fc8335  Morgan EW, Dong F, Annalora AJ, Murray IA, Wol...
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  Takata N, Miska JM, Morgan MA, Patel P, Billin...
# 33d76b34-d7db-505e-a551-233d36740154  Rahiminejad S, Maurya MR, Mukund K, Subramaniam S
#
#                                       landmark
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce     False
# 27147bd8-9969-5750-a964-698000f6944a     False
# 29ddbfb6-4131-5874-ba94-75b664fc8335     False
# 3370a33a-d28e-5027-a3a0-e8489a4259ad     False
# 33d76b34-d7db-505e-a551-233d36740154     False

# %%
dccs = pd.read_csv('output/DCC.tsv', sep="\t", header=None)
dcc_mapper = {}
for i, row in dccs.iterrows():
    dcc_mapper[row[2]] = row[0]
dcc_mapper
# Out:
# {'ExRNA': 'f65babf7-2875-5725-9635-210d654533f1',
#  'Kids First': '65af85ae-82d5-5b81-bc66-6bddaa6420ce',
#  'GTEx': 'b3028db2-209c-5862-8f4d-33c5b312332e',
#  'HuBMAP': '803ad44d-e7a2-550a-95c6-57855bf06be8',
#  'IDG': 'a1289ebb-0306-59a1-b0fc-e4d03a4790d7',
#  'LINCS': 'f3f490cf-fd69-579c-8ea3-472c7cf3fb59',
#  'Metabolomics': '089d8d63-3364-526f-9706-80d62d0ec88c',
#  'MoTrPAC': 'a9aeab22-4fbc-5329-aef6-21110f463c23',
#  'SPARC': '2399794e-74c6-5735-a039-0782cdeeb1e2',
#  'HMP': 'cbfd44b8-684d-56b9-bfd4-45c0e259f896',
#  'Glycoscience': 'e31052b0-ac50-5ede-9828-698ff3610427',
#  'UDN': '7be6ce16-142e-508e-a31f-108e70ce72c2',
#  'KOMP2': '830ddbac-bf21-5612-af1a-75c713045299',
#  'A2CPS': 'e332dadd-8084-5fbc-be41-29d75775aab3',
#  'SenNet': 'dd66e8a5-0e05-5a43-a0ca-18cc3698bb36',
#  'Bridge2AI': '75b3be39-a021-5d80-b7e2-2a7938a1e11a',
#  'iHMP': 'dafdfc72-42c6-5c35-ad56-0b2d284431d1',
#  'H3Africa': '138b48df-8867-5d61-87c5-98cf924c60b9',
#  '4DN': 'd6bb00c3-7224-5001-b9c5-9838622fba40'}

# %%
dcc_pubs = pd.read_csv('output/dcc_publications.tsv', sep="\t", header=None)
dcc_pubs.columns = dcc_pub_cols
dcc_pubs.head()
# Out:
#                          publication_id                                dcc_id
# 0  b2edba84-bdd1-5f3f-855f-8a45e88d98cf  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 1  b3b12752-8f5c-5e5e-8dd0-e46afbc83b4a  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 2  aca50121-fcde-5541-9277-8adf75152db6  b3028db2-209c-5862-8f4d-33c5b312332e
# 3  2337025f-3e71-50ef-850a-a37a4c7fe7ce  803ad44d-e7a2-550a-95c6-57855bf06be8
# 4  7d2732f5-4a7e-5b28-a096-7db93ad1946b  803ad44d-e7a2-550a-95c6-57855bf06be8

# %%
len(dcc_pubs.index)
# Out:
# 44

# %%
lm_pmids = ",".join([str(i) for i in list(landmark.pmid)])
res = requests.get("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=pubmed&id=%s&retmode=json"%lm_pmids)
res.ok
# Out:
# True

# %%
info = res.json()["result"]

# %%
dcc_pub_index = len(dcc_pubs.index)
for i, row in landmark.iterrows():
    pmid = row["pmid"]
    dcc = row["DCC"]
    dcc_id = dcc_mapper[dcc]
    meta = info[str(pmid)]
    title = meta["title"]
    uid = uuid5(NAMESPACE_URL, title)
    year = meta["sortpubdate"].split("/")[0]
    page = meta["pages"]
    volume = meta["volume"]
    issue = meta["issue"]
    journal = meta["fulljournalname"]
    pmcid = ''
    doi = ''
    for i in meta["articleids"]:
        if i["idtype"] == 'pmcid':
            pmcid = i['value'].split(";")[0].replace("pmc-id: ","").strip()
        if i["idtype"] == 'doi':
            doi = i['value']
    authors = ", ".join([i["name"] for i in meta["authors"]])
    publications.loc[uid] = [
        title,
        year,
        page,
        volume,
        issue,
        journal,
        pmid,
        pmcid,
        doi,
        authors,
        True
    ]
    dcc_pubs.loc[dcc_pub_index] = [
        uid,
        dcc_id
    ]
    dcc_pub_index += 1

# %%
dcc_pubs.shape
# Out:
# (61, 2)

# %%
publications.head()
# Out:
#                                                                                   title  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  3D virtual reality vs. 2D desktop registration...
# 27147bd8-9969-5750-a964-698000f6944a  Computational screen to identify potential tar...
# 29ddbfb6-4131-5874-ba94-75b664fc8335  Contribution of Circulating Host and Microbial...
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  Lactate-dependent transcriptional regulation c...
# 33d76b34-d7db-505e-a551-233d36740154  Modular and mechanistic changes across stages ...
#
#                                       year               page volume issue  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  2021           e0258103     16    10
# 27147bd8-9969-5750-a964-698000f6944a  2023             e13809     22     6
# 29ddbfb6-4131-5874-ba94-75b664fc8335  2023  11786469231182510     16   NaN
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  2023               4129     14     1
# 33d76b34-d7db-505e-a551-233d36740154  2022                436     22     1
#
#                                                                                 journal  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce                                           PloS one
# 27147bd8-9969-5750-a964-698000f6944a                                         Aging cell
# 29ddbfb6-4131-5874-ba94-75b664fc8335  International journal of tryptophan research :...
# 3370a33a-d28e-5027-a3a0-e8489a4259ad                              Nature communications
# 33d76b34-d7db-505e-a551-233d36740154                                         BMC cancer
#
#                                           pmid        pmcid  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  34705835   PMC8550408
# 27147bd8-9969-5750-a964-698000f6944a  37082798  PMC10265163
# 29ddbfb6-4131-5874-ba94-75b664fc8335  37441265  PMC10334013
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  37452018  PMC10349100
# 33d76b34-d7db-505e-a551-233d36740154  35448980   PMC9022252
#
#                                                                doi  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  10.1371/journal.pone.0258103
# 27147bd8-9969-5750-a964-698000f6944a            10.1111/acel.13809
# 29ddbfb6-4131-5874-ba94-75b664fc8335     10.1177/11786469231182510
# 3370a33a-d28e-5027-a3a0-e8489a4259ad    10.1038/s41467-023-39672-2
# 33d76b34-d7db-505e-a551-233d36740154    10.1186/s12885-022-09479-3
#
#                                                                                 authors  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce           Bueckle A, Buehling K, Shih PC, Borner K
# 27147bd8-9969-5750-a964-698000f6944a  Deng EZ, Fleishman RH, Xie Z, Marino GB, Clark...
# 29ddbfb6-4131-5874-ba94-75b664fc8335  Morgan EW, Dong F, Annalora AJ, Murray IA, Wol...
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  Takata N, Miska JM, Morgan MA, Patel P, Billin...
# 33d76b34-d7db-505e-a551-233d36740154  Rahiminejad S, Maurya MR, Mukund K, Subramaniam S
#
#                                       landmark
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce     False
# 27147bd8-9969-5750-a964-698000f6944a     False
# 29ddbfb6-4131-5874-ba94-75b664fc8335     False
# 3370a33a-d28e-5027-a3a0-e8489a4259ad     False
# 33d76b34-d7db-505e-a551-233d36740154     False

# %%
publications.to_csv('output/publications.tsv', header=None, sep="\t")
dcc_pubs.to_csv('output/dcc_publications.tsv', header=None, index=None, sep="\t")

# %%
dccs.head()
# Out:
#                                       0  \
# 0  f65babf7-2875-5725-9635-210d654533f1
# 1  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 2  b3028db2-209c-5862-8f4d-33c5b312332e
# 3  803ad44d-e7a2-550a-95c6-57855bf06be8
# 4  a1289ebb-0306-59a1-b0fc-e4d03a4790d7
#
#                                                 1           2  \
# 0                 Extracellular RNA Communication       ExRNA
# 1  Gabriella Miller Kids First Pediatric Research  Kids First
# 2                      Genotype Tissue Expression        GTEx
# 3                Human BioMolecular Atlas Program      HuBMAP
# 4               Illuminating the Druggable Genome         IDG
#
#                                                    3  \
# 0  The Extracellular RNA Communication program is...
# 1  The goal of the Gabriella Miller Kids First Pe...
# 2  The Common Fund's Genotype-Tissue Expression (...
# 3  The goal of the Human BioMolecular Atlas Progr...
# 4  To improve our scientific understanding of und...
#
#                                   4                    5     6  \
# 0                https://exrna.org/       /img/exRNA.png  True
# 1         https://kidsfirstdrc.org/  /img/Kids First.png  True
# 2  https://www.gtexportal.org/home/        /img/GTEx.png  True
# 3     https://hubmapconsortium.org/      /img/HuBMAP.png  True
# 4      https://druggablegenome.net/         /img/IDG.png  True
#
#                                       7
# 0      https://commonfund.nih.gov/ExRNA
# 1  https://commonfund.nih.gov/KidsFirst
# 2       https://commonfund.nih.gov/GTEx
# 3     https://commonfund.nih.gov/HuBMAP
# 4        https://commonfund.nih.gov/IDG

# %%
partnerships = pd.read_csv('data/partnership.tsv', sep="\t")
partnerships.head()
# Out:
#                                          Partnership  \
# 0                   Gene Centric Prototype Dashboard
# 1  Clinical Observations and Vocabularies (CLOVoc...
# 2  Aggregation and Sharing of Variant-Centric Inf...
# 3         Reproductive Toxicology Screening Pipeline
# 4                          Playbook Workflow Builder
#
#                                                Goals  \
# 0  This project developed methods to harmonize ge...
# 1  The goal of the CLOVoc project was to improve ...
# 2  This project aimed to make CFDE variant data F...
# 3  This project developed a knowledge graph that ...
# 4  This project develops an interactive workflow ...
#
#                                   Participating DCCs     Status  \
# 0  exRNA; GlyGen; GTEx; HuBMAP; IDG; Kids First; ...  completed
# 1                    Kids First; Metabolomics; SPARC  completed
# 2                            exRNA; GTEx; Kids First  Completed
# 3                      IDG; Kids First; LINCS; SPARC  completed
# 4     exRNA; GlyGen; Kids First; LINCS; Metabolomics     active
#
#                             Publication  \
# 0  cf8499b5-8f1a-5ef8-8d17-05cb5c27bd16
# 1                                   NaN
# 2                                   NaN
# 3  b2edba84-bdd1-5f3f-855f-8a45e88d98cf
# 4                                   NaN
#
#                                     Website
# 0            https://cfde-gene-pages.cloud/
# 1                                       NaN
# 2                                       NaN
# 3       https://maayanlab.cloud/reprotox-kg
# 4  https://playbook-workflow-builder.cloud/

# %%
cols = ["id", "title", "description", "status", "website", "image"]

# %%
cf_name_mapper = {
 'exRNA': 'ExRNA',
 'KidsFirst': 'Kids First',
 'Kids First': 'Kids First',
 'GTEx': 'GTEx',
 'HuBMAP': 'HuBMAP',
 'IDG': 'IDG',
 'LINCS': 'LINCS',
 'Metabolomics': 'Metabolomics',
 'MW': 'Metabolomics',
 'MoTrPAC': 'MolecularTransducers',
 'SPARC': 'SPARC',
 'HMP': 'HMP',
 'GlyGen': 'Glycoscience',
 'UDN': 'Diseases',
 'KOMP2': 'KOMP2',
 'A2CPS': 'pain',
 'SenNet': 'senescence',
 'Bridge2AI': 'Bridge2AI',
 'iHMP': 'HMP',
 'H3Africa': 'global-health',
 '4DN': '4DN',
 }

# %%
partnership_list = []
dcc_partnership_list = []
partnership_publications = []
for i, row in partnerships.iterrows():
    title = row["Partnership"]
    description = row["Goals"]
    status = row["Status"]
    website = row["Website"]
    publication = row["Publication"]
    image = ""
    uid = str(uuid5(NAMESPACE_URL, title))
    partnership_list.append([
        uid,
        title,
        description,
        status,
        website,
        image,
    ])
    for d in row["Participating DCCs"].split("; "):
        dcc = cf_name_mapper[d]
        dcc_id = dcc_mapper[dcc]
        dcc_partnership_list.append([
            uid,
            dcc_id
        ])
    if type(publication) == str:
        partnership_publications.append([
            uid,
            publication
        ])

# %%
partnership_df = pd.DataFrame(partnership_list, columns=cols, index=range(0, len(partnership_list)))
dcc_partnership = pd.DataFrame(dcc_partnership_list, columns=['partnership_id', 'dcc_id'], index=range(0, len(dcc_partnership_list)))
partnership_publications_df = pd.DataFrame(partnership_publications, columns=['partnership_id', 'publication_id'], index=range(0, len(partnership_publications)))
partnership_df = partnership_df.set_index("id")
partnership_df.head()
# Out:
#                                                                                   title  \
# id
# e845c285-c12b-5e6e-925d-80f5b05e9e13                   Gene Centric Prototype Dashboard
# 47d5dd85-6743-5b68-9261-8654ccd86c30  Clinical Observations and Vocabularies (CLOVoc...
# f2e7a2d0-eaa9-578e-a9d3-089daf63ee4c  Aggregation and Sharing of Variant-Centric Inf...
# 6cf0e595-26a5-519f-97be-aa60c996b79c         Reproductive Toxicology Screening Pipeline
# 08cd40cc-f35f-547f-a8d7-524859559b0c                          Playbook Workflow Builder
#
#                                                                             description  \
# id
# e845c285-c12b-5e6e-925d-80f5b05e9e13  This project developed methods to harmonize ge...
# 47d5dd85-6743-5b68-9261-8654ccd86c30  The goal of the CLOVoc project was to improve ...
# f2e7a2d0-eaa9-578e-a9d3-089daf63ee4c  This project aimed to make CFDE variant data F...
# 6cf0e595-26a5-519f-97be-aa60c996b79c  This project developed a knowledge graph that ...
# 08cd40cc-f35f-547f-a8d7-524859559b0c  This project develops an interactive workflow ...
#
#                                          status  \
# id
# e845c285-c12b-5e6e-925d-80f5b05e9e13  completed
# 47d5dd85-6743-5b68-9261-8654ccd86c30  completed
# f2e7a2d0-eaa9-578e-a9d3-089daf63ee4c  Completed
# 6cf0e595-26a5-519f-97be-aa60c996b79c  completed
# 08cd40cc-f35f-547f-a8d7-524859559b0c     active
#
#                                                                        website  \
# id
# e845c285-c12b-5e6e-925d-80f5b05e9e13            https://cfde-gene-pages.cloud/
# 47d5dd85-6743-5b68-9261-8654ccd86c30                                       NaN
# f2e7a2d0-eaa9-578e-a9d3-089daf63ee4c                                       NaN
# 6cf0e595-26a5-519f-97be-aa60c996b79c       https://maayanlab.cloud/reprotox-kg
# 08cd40cc-f35f-547f-a8d7-524859559b0c  https://playbook-workflow-builder.cloud/
#
#                                      image
# id
# e845c285-c12b-5e6e-925d-80f5b05e9e13
# 47d5dd85-6743-5b68-9261-8654ccd86c30
# f2e7a2d0-eaa9-578e-a9d3-089daf63ee4c
# 6cf0e595-26a5-519f-97be-aa60c996b79c
# 08cd40cc-f35f-547f-a8d7-524859559b0c

# %%
dcc_partnership
# Out:
#                           partnership_id                                dcc_id
# 0   e845c285-c12b-5e6e-925d-80f5b05e9e13  f65babf7-2875-5725-9635-210d654533f1
# 1   e845c285-c12b-5e6e-925d-80f5b05e9e13  e31052b0-ac50-5ede-9828-698ff3610427
# 2   e845c285-c12b-5e6e-925d-80f5b05e9e13  b3028db2-209c-5862-8f4d-33c5b312332e
# 3   e845c285-c12b-5e6e-925d-80f5b05e9e13  803ad44d-e7a2-550a-95c6-57855bf06be8
# 4   e845c285-c12b-5e6e-925d-80f5b05e9e13  a1289ebb-0306-59a1-b0fc-e4d03a4790d7
# 5   e845c285-c12b-5e6e-925d-80f5b05e9e13  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 6   e845c285-c12b-5e6e-925d-80f5b05e9e13  f3f490cf-fd69-579c-8ea3-472c7cf3fb59
# 7   e845c285-c12b-5e6e-925d-80f5b05e9e13  089d8d63-3364-526f-9706-80d62d0ec88c
# 8   47d5dd85-6743-5b68-9261-8654ccd86c30  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 9   47d5dd85-6743-5b68-9261-8654ccd86c30  089d8d63-3364-526f-9706-80d62d0ec88c
# 10  47d5dd85-6743-5b68-9261-8654ccd86c30  2399794e-74c6-5735-a039-0782cdeeb1e2
# 11  f2e7a2d0-eaa9-578e-a9d3-089daf63ee4c  f65babf7-2875-5725-9635-210d654533f1
# 12  f2e7a2d0-eaa9-578e-a9d3-089daf63ee4c  b3028db2-209c-5862-8f4d-33c5b312332e
# 13  f2e7a2d0-eaa9-578e-a9d3-089daf63ee4c  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 14  6cf0e595-26a5-519f-97be-aa60c996b79c  a1289ebb-0306-59a1-b0fc-e4d03a4790d7
# 15  6cf0e595-26a5-519f-97be-aa60c996b79c  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 16  6cf0e595-26a5-519f-97be-aa60c996b79c  f3f490cf-fd69-579c-8ea3-472c7cf3fb59
# 17  6cf0e595-26a5-519f-97be-aa60c996b79c  2399794e-74c6-5735-a039-0782cdeeb1e2
# 18  08cd40cc-f35f-547f-a8d7-524859559b0c  f65babf7-2875-5725-9635-210d654533f1
# 19  08cd40cc-f35f-547f-a8d7-524859559b0c  e31052b0-ac50-5ede-9828-698ff3610427
# 20  08cd40cc-f35f-547f-a8d7-524859559b0c  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 21  08cd40cc-f35f-547f-a8d7-524859559b0c  f3f490cf-fd69-579c-8ea3-472c7cf3fb59
# 22  08cd40cc-f35f-547f-a8d7-524859559b0c  089d8d63-3364-526f-9706-80d62d0ec88c
# 23  bfc1de56-d2d0-524b-acf2-30a71a3fbce3  b3028db2-209c-5862-8f4d-33c5b312332e
# 24  bfc1de56-d2d0-524b-acf2-30a71a3fbce3  803ad44d-e7a2-550a-95c6-57855bf06be8
# 25  bfc1de56-d2d0-524b-acf2-30a71a3fbce3  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 26  bfc1de56-d2d0-524b-acf2-30a71a3fbce3  2399794e-74c6-5735-a039-0782cdeeb1e2
# 27  b08fa45b-a979-509a-a3a5-de9616bec4e1  d6bb00c3-7224-5001-b9c5-9838622fba40
# 28  b08fa45b-a979-509a-a3a5-de9616bec4e1  f65babf7-2875-5725-9635-210d654533f1
# 29  b08fa45b-a979-509a-a3a5-de9616bec4e1  e31052b0-ac50-5ede-9828-698ff3610427
# 30  b08fa45b-a979-509a-a3a5-de9616bec4e1  b3028db2-209c-5862-8f4d-33c5b312332e
# 31  b08fa45b-a979-509a-a3a5-de9616bec4e1  803ad44d-e7a2-550a-95c6-57855bf06be8
# 32  b08fa45b-a979-509a-a3a5-de9616bec4e1  a1289ebb-0306-59a1-b0fc-e4d03a4790d7
# 33  b08fa45b-a979-509a-a3a5-de9616bec4e1  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 34  b08fa45b-a979-509a-a3a5-de9616bec4e1  f3f490cf-fd69-579c-8ea3-472c7cf3fb59
# 35  b08fa45b-a979-509a-a3a5-de9616bec4e1  089d8d63-3364-526f-9706-80d62d0ec88c
# 36  b08fa45b-a979-509a-a3a5-de9616bec4e1  2399794e-74c6-5735-a039-0782cdeeb1e2
# 37  55712735-975d-5723-8bad-4294f0c743e2  f65babf7-2875-5725-9635-210d654533f1
# 38  55712735-975d-5723-8bad-4294f0c743e2  b3028db2-209c-5862-8f4d-33c5b312332e
# 39  55712735-975d-5723-8bad-4294f0c743e2  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 40  0be2149f-00bc-545d-948c-4313b5106858  e31052b0-ac50-5ede-9828-698ff3610427
# 41  0be2149f-00bc-545d-948c-4313b5106858  a1289ebb-0306-59a1-b0fc-e4d03a4790d7
# 42  0be2149f-00bc-545d-948c-4313b5106858  089d8d63-3364-526f-9706-80d62d0ec88c
# 43  0be2149f-00bc-545d-948c-4313b5106858  f3f490cf-fd69-579c-8ea3-472c7cf3fb59
# 44  0be2149f-00bc-545d-948c-4313b5106858  803ad44d-e7a2-550a-95c6-57855bf06be8

# %%
partnership_df.to_csv('output/partnerships.tsv', sep="\t", header=None)
dcc_partnership.to_csv('output/dcc_partnerships.tsv', sep="\t", header=None, index=None)
partnership_publications_df.to_csv('output/partnership_publications.tsv', sep="\t", header=None, index=None)

# %%
cf_name_mapper = {
 'ExRNA': 'ExRNA',
 'Kids First': 'KidsFirst',
 'GTEx': 'GTEx',
 'HuBMAP': 'HuBMAP',
 'IDG': 'IDG',
 'LINCS': 'LINCS',
 'Metabolomics': 'Metabolomics',
 'MoTrPAC': 'MolecularTransducers',
 'SPARC': 'SPARC',
 'HMP': 'HMP',
 'Glycoscience': 'Glycoscience',
 'UDN': 'Diseases',
 'KOMP2': 'KOMP2',
 'A2CPS': 'pain',
 'SenNet': 'senescence',
 'Bridge2AI': 'Bridge2AI',
 'iHMP': 'HMP',
 'H3Africa': 'global-health',
 '4DN': '4DN',
 }

# %%
dccs
# Out:
#                                        0  \
# 0   f65babf7-2875-5725-9635-210d654533f1
# 1   65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 2   b3028db2-209c-5862-8f4d-33c5b312332e
# 3   803ad44d-e7a2-550a-95c6-57855bf06be8
# 4   a1289ebb-0306-59a1-b0fc-e4d03a4790d7
# 5   f3f490cf-fd69-579c-8ea3-472c7cf3fb59
# 6   089d8d63-3364-526f-9706-80d62d0ec88c
# 7   a9aeab22-4fbc-5329-aef6-21110f463c23
# 8   2399794e-74c6-5735-a039-0782cdeeb1e2
# 9   cbfd44b8-684d-56b9-bfd4-45c0e259f896
# 10  e31052b0-ac50-5ede-9828-698ff3610427
# 11  7be6ce16-142e-508e-a31f-108e70ce72c2
# 12  830ddbac-bf21-5612-af1a-75c713045299
# 13  e332dadd-8084-5fbc-be41-29d75775aab3
# 14  dd66e8a5-0e05-5a43-a0ca-18cc3698bb36
# 15  75b3be39-a021-5d80-b7e2-2a7938a1e11a
# 16  dafdfc72-42c6-5c35-ad56-0b2d284431d1
# 17  138b48df-8867-5d61-87c5-98cf924c60b9
# 18  d6bb00c3-7224-5001-b9c5-9838622fba40
#
#                                                     1             2  \
# 0                     Extracellular RNA Communication         ExRNA
# 1      Gabriella Miller Kids First Pediatric Research    Kids First
# 2                          Genotype Tissue Expression          GTEx
# 3                    Human BioMolecular Atlas Program        HuBMAP
# 4                   Illuminating the Druggable Genome           IDG
# 5   Library of Integrated Network-based Cellular S...         LINCS
# 6                                        Metabolomics  Metabolomics
# 7   Molecular Transducers of Physical Activity Con...       MoTrPAC
# 8   Stimulating Peripheral Activity to Relieve Con...         SPARC
# 9                        The Human Microbiome Project           HMP
# 10                                       Glycoscience  Glycoscience
# 11                       Undiagnosed Diseases Network           UDN
# 12                 Knockout Mouse Phenotyping Program         KOMP2
# 13                   Acute to Chronic Pain Signatures         A2CPS
# 14                    The Cellular Senescence Network        SenNet
# 15                  Bridge to Artificial Intelligence     Bridge2AI
# 16           NIH Integrative Human Microbiome Project          iHMP
# 17                  Human Heredity & Health in Africa      H3Africa
# 18                                        4D Nucleome           4DN
#
#                                                     3  \
# 0   The Extracellular RNA Communication program is...
# 1   The goal of the Gabriella Miller Kids First Pe...
# 2   The Common Fund's Genotype-Tissue Expression (...
# 3   The goal of the Human BioMolecular Atlas Progr...
# 4   To improve our scientific understanding of und...
# 5   The Common Fund’s Library of Integrated Networ...
# 6   The goal of the Common Fund’s Metabolomics pro...
# 7   The Molecular Transducers of Physical Activity...
# 8   The Common Fund’s Stimulating Peripheral Activ...
# 9   The Common Fund's Human Microbiome Project (HM...
# 10  The goal of the Common Fund’s Glycoscience pro...
# 11  The NIH Undiagnosed Diseases Network (UDN) is ...
# 12  The Knockout Mouse Phenotyping Program (KOMP2)...
# 13  The goal of the Acute to Chronic Pain Signatur...
# 14  The Common Fund’s Cellular Senescence Network ...
# 15  The NIH Common Fund’s Bridge to Artificial Int...
# 16  The NIH Common Fund Human Microbiome Project (...
# 17  H3Africa Consortium facilities modern research...
# 18  The goal of the Common Fund’s 4D Nucleome (4DN...
#
#                                          4                      5      6  \
# 0                       https://exrna.org/         /img/exRNA.png   True
# 1                https://kidsfirstdrc.org/    /img/Kids First.png   True
# 2         https://www.gtexportal.org/home/          /img/GTEx.png   True
# 3            https://hubmapconsortium.org/        /img/HuBMAP.png   True
# 4             https://druggablegenome.net/           /img/IDG.png   True
# 5                https://lincsproject.org/         /img/LINCS.gif   True
# 6   https://www.metabolomicsworkbench.org/  /img/Metabolomics.png   True
# 7                 https://www.motrpac.org/       /img/MoTrPAC.png   True
# 8                   https://sparc.science/         /img/SPARC.svg   True
# 9              https://portal.hmpdacc.org/           /img/HMP.png   True
# 10                 https://www.glygen.org/  /img/Glycoscience.png   True
# 11    https://undiagnosed.hms.harvard.edu/           /img/UDN.png   True
# 12         https://www.mousephenotype.org/         /img/KOMP2.svg   True
# 13                      https://a2cps.org/         /img/A2CPS.png  False
# 14           https://sennetconsortium.org/        /img/SenNet.png  False
# 15                  https://bridge2ai.org/     /img/Bridge2AI.png   True
# 16           https://www.hmpdacc.org/ihmp/          /img/ihmp.png  False
# 17                   https://h3africa.org/      /img/h3africa.png   True
# 18             https://www.4dnucleome.org/           /img/4DN.png   True
#
#                                                   7
# 0                  https://commonfund.nih.gov/ExRNA
# 1              https://commonfund.nih.gov/KidsFirst
# 2                   https://commonfund.nih.gov/GTEx
# 3                 https://commonfund.nih.gov/HuBMAP
# 4                    https://commonfund.nih.gov/IDG
# 5                  https://commonfund.nih.gov/LINCS
# 6           https://commonfund.nih.gov/Metabolomics
# 7   https://commonfund.nih.gov/MolecularTransducers
# 8                  https://commonfund.nih.gov/SPARC
# 9                    https://commonfund.nih.gov/HMP
# 10          https://commonfund.nih.gov/Glycoscience
# 11              https://commonfund.nih.gov/Diseases
# 12                 https://commonfund.nih.gov/KOMP2
# 13                  https://commonfund.nih.gov/pain
# 14            https://commonfund.nih.gov/senescence
# 15             https://commonfund.nih.gov/Bridge2AI
# 16                   https://commonfund.nih.gov/HMP
# 17         https://commonfund.nih.gov/global-health
# 18                   https://commonfund.nih.gov/4DN

# %%
dccs.columns = ["id", "label", "short_label", "description", "homepage", "icon", "cfde_partner", 'cf_site']
dccs.head()
# Out:
#                                      id  \
# 0  f65babf7-2875-5725-9635-210d654533f1
# 1  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 2  b3028db2-209c-5862-8f4d-33c5b312332e
# 3  803ad44d-e7a2-550a-95c6-57855bf06be8
# 4  a1289ebb-0306-59a1-b0fc-e4d03a4790d7
#
#                                             label short_label  \
# 0                 Extracellular RNA Communication       ExRNA
# 1  Gabriella Miller Kids First Pediatric Research  Kids First
# 2                      Genotype Tissue Expression        GTEx
# 3                Human BioMolecular Atlas Program      HuBMAP
# 4               Illuminating the Druggable Genome         IDG
#
#                                          description  \
# 0  The Extracellular RNA Communication program is...
# 1  The goal of the Gabriella Miller Kids First Pe...
# 2  The Common Fund's Genotype-Tissue Expression (...
# 3  The goal of the Human BioMolecular Atlas Progr...
# 4  To improve our scientific understanding of und...
#
#                            homepage                 icon  cfde_partner  \
# 0                https://exrna.org/       /img/exRNA.png          True
# 1         https://kidsfirstdrc.org/  /img/Kids First.png          True
# 2  https://www.gtexportal.org/home/        /img/GTEx.png          True
# 3     https://hubmapconsortium.org/      /img/HuBMAP.png          True
# 4      https://druggablegenome.net/         /img/IDG.png          True
#
#                                 cf_site
# 0      https://commonfund.nih.gov/ExRNA
# 1  https://commonfund.nih.gov/KidsFirst
# 2       https://commonfund.nih.gov/GTEx
# 3     https://commonfund.nih.gov/HuBMAP
# 4        https://commonfund.nih.gov/IDG

# %%
dccs.cf_site = ''
for i,row in dccs.iterrows():
    short_label = row["short_label"]
    cf = cf_name_mapper[short_label]
    dccs.at[i, 'cf_site'] = "https://commonfund.nih.gov/%s"%cf
    dccs.at[i, 'description'] = row["description"].replace(" (Description was taken from: https://commonfund.nih.gov.)", "")
dccs.head()
# Out:
#                                      id  \
# 0  f65babf7-2875-5725-9635-210d654533f1
# 1  65af85ae-82d5-5b81-bc66-6bddaa6420ce
# 2  b3028db2-209c-5862-8f4d-33c5b312332e
# 3  803ad44d-e7a2-550a-95c6-57855bf06be8
# 4  a1289ebb-0306-59a1-b0fc-e4d03a4790d7
#
#                                             label short_label  \
# 0                 Extracellular RNA Communication       ExRNA
# 1  Gabriella Miller Kids First Pediatric Research  Kids First
# 2                      Genotype Tissue Expression        GTEx
# 3                Human BioMolecular Atlas Program      HuBMAP
# 4               Illuminating the Druggable Genome         IDG
#
#                                          description  \
# 0  The Extracellular RNA Communication program is...
# 1  The goal of the Gabriella Miller Kids First Pe...
# 2  The Common Fund's Genotype-Tissue Expression (...
# 3  The goal of the Human BioMolecular Atlas Progr...
# 4  To improve our scientific understanding of und...
#
#                            homepage                 icon  cfde_partner  \
# 0                https://exrna.org/       /img/exRNA.png          True
# 1         https://kidsfirstdrc.org/  /img/Kids First.png          True
# 2  https://www.gtexportal.org/home/        /img/GTEx.png          True
# 3     https://hubmapconsortium.org/      /img/HuBMAP.png          True
# 4      https://druggablegenome.net/         /img/IDG.png          True
#
#                                 cf_site
# 0      https://commonfund.nih.gov/ExRNA
# 1  https://commonfund.nih.gov/KidsFirst
# 2       https://commonfund.nih.gov/GTEx
# 3     https://commonfund.nih.gov/HuBMAP
# 4        https://commonfund.nih.gov/IDG

# %%
dccs.to_csv("output/DCC.tsv", sep="\t", header=None, index=None)

# %%
pmid = "31677972"

# %%
publications = pd.read_csv('output/publications.tsv', sep="\t", header=None)
publications.columns = pub_cols
publications = publications.set_index("id")
publications.head()
# Out:
#                                                                                   title  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  3D virtual reality vs. 2D desktop registration...
# 27147bd8-9969-5750-a964-698000f6944a  Computational screen to identify potential tar...
# 29ddbfb6-4131-5874-ba94-75b664fc8335  Contribution of Circulating Host and Microbial...
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  Lactate-dependent transcriptional regulation c...
# 33d76b34-d7db-505e-a551-233d36740154  Modular and mechanistic changes across stages ...
#
#                                       year               page  volume issue  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  2021           e0258103      16    10
# 27147bd8-9969-5750-a964-698000f6944a  2023             e13809      22     6
# 29ddbfb6-4131-5874-ba94-75b664fc8335  2023  11786469231182510      16   NaN
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  2023               4129      14     1
# 33d76b34-d7db-505e-a551-233d36740154  2022                436      22     1
#
#                                                                                 journal  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce                                           PloS one
# 27147bd8-9969-5750-a964-698000f6944a                                         Aging cell
# 29ddbfb6-4131-5874-ba94-75b664fc8335  International journal of tryptophan research :...
# 3370a33a-d28e-5027-a3a0-e8489a4259ad                              Nature communications
# 33d76b34-d7db-505e-a551-233d36740154                                         BMC cancer
#
#                                           pmid        pmcid  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  34705835   PMC8550408
# 27147bd8-9969-5750-a964-698000f6944a  37082798  PMC10265163
# 29ddbfb6-4131-5874-ba94-75b664fc8335  37441265  PMC10334013
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  37452018  PMC10349100
# 33d76b34-d7db-505e-a551-233d36740154  35448980   PMC9022252
#
#                                                                doi  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce  10.1371/journal.pone.0258103
# 27147bd8-9969-5750-a964-698000f6944a            10.1111/acel.13809
# 29ddbfb6-4131-5874-ba94-75b664fc8335     10.1177/11786469231182510
# 3370a33a-d28e-5027-a3a0-e8489a4259ad    10.1038/s41467-023-39672-2
# 33d76b34-d7db-505e-a551-233d36740154    10.1186/s12885-022-09479-3
#
#                                                                                 authors  \
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce           Bueckle A, Buehling K, Shih PC, Borner K
# 27147bd8-9969-5750-a964-698000f6944a  Deng EZ, Fleishman RH, Xie Z, Marino GB, Clark...
# 29ddbfb6-4131-5874-ba94-75b664fc8335  Morgan EW, Dong F, Annalora AJ, Murray IA, Wol...
# 3370a33a-d28e-5027-a3a0-e8489a4259ad  Takata N, Miska JM, Morgan MA, Patel P, Billin...
# 33d76b34-d7db-505e-a551-233d36740154  Rahiminejad S, Maurya MR, Mukund K, Subramaniam S
#
#                                       landmark
# id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce     False
# 27147bd8-9969-5750-a964-698000f6944a     False
# 29ddbfb6-4131-5874-ba94-75b664fc8335     False
# 3370a33a-d28e-5027-a3a0-e8489a4259ad     False
# 33d76b34-d7db-505e-a551-233d36740154     False

# %%
res = requests.get("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi?db=pubmed&id=%s&retmode=json"%pmid)
res.ok
# Out:
# True

# %%
info = res.json()["result"]
dcc_pub_index = len(dcc_pubs.index)
meta = info[str(pmid)]
title = meta["title"]
uid = uuid5(NAMESPACE_URL, title)
year = meta["sortpubdate"].split("/")[0]
page = meta["pages"]
volume = meta["volume"]
issue = meta["issue"]
journal = meta["fulljournalname"]
pmcid = ''
doi = ''
for i in meta["articleids"]:
    if i["idtype"] == 'pmcid':
        pmcid = i['value'].split(";")[0].replace("pmc-id: ","").strip()
    if i["idtype"] == 'doi':
        doi = i['value']
authors = ", ".join([i["name"] for i in meta["authors"]])
publications.loc[uid] = [
    title,
    year,
    page,
    volume,
    issue,
    journal,
    pmid,
    pmcid,
    doi,
    authors,
    False
]

# %%
publications.to_csv("output/publications.tsv", sep="\t", header=None)

# %%
publications.tool_id = ''

# %%
publications = pd.read_csv('output/publications.tsv', sep="\t", index_col=0)
publications.tail()
# Out:
#                                      3D virtual reality vs. 2D desktop registration user interface comparison.  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612  GlyGen: Computational and Informatics Resource...
# f02b60a9-a6c9-51fd-9988-bc16b539826b  High-throughput discovery of novel development...
# 2e951d34-e979-5c94-a808-f43f467b7121                    H3Africa: current perspectives.
# 874e4f27-c310-51ad-a8c7-749f16baca7c  Machine Learning of Patient Characteristics to...
# 655656e6-8a48-52a1-b973-3d53768d4d04  FAIRshake: Toolkit to Evaluate the FAIRness of...
#
#                                       2021  e0258103   16    10  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612  2020     72-73   30     2
# f02b60a9-a6c9-51fd-9988-bc16b539826b  2016   508-514  537  7621
# 2e951d34-e979-5c94-a808-f43f467b7121  2018     59-66   11   NaN
# 874e4f27-c310-51ad-a8c7-749f16baca7c  2021  e2036220    4     2
# 655656e6-8a48-52a1-b973-3d53768d4d04  2019   417-421    9     5
#
#                                                                         PloS one  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612                                Glycobiology
# f02b60a9-a6c9-51fd-9988-bc16b539826b                                      Nature
# 2e951d34-e979-5c94-a808-f43f467b7121  Pharmacogenomics and personalized medicine
# 874e4f27-c310-51ad-a8c7-749f16baca7c                           JAMA network open
# 655656e6-8a48-52a1-b973-3d53768d4d04                                Cell systems
#
#                                       34705835  PMC8550408  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612  31616925  PMC7335483
# f02b60a9-a6c9-51fd-9988-bc16b539826b  27626380  PMC5295821
# 2e951d34-e979-5c94-a808-f43f467b7121  29692621  PMC5903476
# 874e4f27-c310-51ad-a8c7-749f16baca7c  33630084  PMC7907957
# 655656e6-8a48-52a1-b973-3d53768d4d04  31677972  PMC7316196
#
#                                             10.1371/journal.pone.0258103  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612               10.1093/glycob/cwz080
# f02b60a9-a6c9-51fd-9988-bc16b539826b                 10.1038/nature19356
# 2e951d34-e979-5c94-a808-f43f467b7121                10.2147/PGPM.S141546
# 874e4f27-c310-51ad-a8c7-749f16baca7c  10.1001/jamanetworkopen.2020.36220
# 655656e6-8a48-52a1-b973-3d53768d4d04          10.1016/j.cels.2019.09.011
#
#                                                Bueckle A, Buehling K, Shih PC, Borner K  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612  York WS, Mazumder R, Ranzinger R, Edwards N, K...
# f02b60a9-a6c9-51fd-9988-bc16b539826b  Dickinson ME, Flenniken AM, Ji X, Teboul L, Wo...
# 2e951d34-e979-5c94-a808-f43f467b7121  Mulder N, Abimiku A, Adebamowo SN, de Vries J,...
# 874e4f27-c310-51ad-a8c7-749f16baca7c   Amiri H, Kohane IS, Undiagnosed Diseases Network
# 655656e6-8a48-52a1-b973-3d53768d4d04  Clarke DJB, Wang L, Jones A, Wojciechowicz ML,...
#
#                                       False
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612   True
# f02b60a9-a6c9-51fd-9988-bc16b539826b   True
# 2e951d34-e979-5c94-a808-f43f467b7121   True
# 874e4f27-c310-51ad-a8c7-749f16baca7c   True
# 655656e6-8a48-52a1-b973-3d53768d4d04  False

# %%
tools = pd.read_csv("data/tools.tsv", sep="\t")
tools.head()
# Out:
#                               Name  \
# 0        Playbook Workflow Builder
# 1                            GDLPA
# 2                        FAIRshake
# 3                      ReproTox-KG
# 4  Data Distillery Knowledge Graph
#
#                                          Description  \
# 0  The Common Fund Data Ecosystem (CFDE) Playbook...
# 1  Gene and Drug Landing Page Aggregator (GDLPA) ...
# 2  The FAIRshake toolkit was developed to enable ...
# 3  To further characterize associations between s...
# 4  The Unified Biomedical Knowledge Graph (UBKG) ...
#
#                                                  URL  \
# 0           https://playbook-workflow-builder.cloud/
# 1                     https://cfde-gene-pages.cloud/
# 2                           https://fairshake.cloud/
# 3                https://maayanlab.cloud/reprotox-kg
# 4  https://github.com/TaylorResearchLab/CFDE_Data...
#
#                                           DOI                      Image  \
# 0                                         NaN               /img/pwb.png
# 1      https://doi.org/10.1093/bioadv/vbac013             /img/gdlpa.png
# 2  https://doi.org/10.1016/j.cels.2019.09.011         /img/fairshake.png
# 3  https://doi.org/10.1038/s43856-023-00329-2  /img/reprotox-kg-logo.png
# 4                                         NaN              /img/ubkg.png
#
#                             Publication
# 0                                   NaN
# 1  cf8499b5-8f1a-5ef8-8d17-05cb5c27bd16
# 2  655656e6-8a48-52a1-b973-3d53768d4d04
# 3  b2edba84-bdd1-5f3f-855f-8a45e88d98cf
# 4                                   NaN

# %%
tools.id = ""
tool_list = []
for i, row in tools.iterrows():
     uid = str(uuid5(NAMESPACE_URL, row["Name"]))
     tool_list.append([
          uid,
          row["Name"],
          row["Description"],
          row["URL"],
          row["Image"]
     ])
     if type(row["Publication"]) == str:
          if row["Publication"] not in publications.index:
               print(row["Publication"])
          else:
               publications.at[row["Publication"], 'tool_id'] = uid
# Out:
# /var/folders/wq/7bkxhy8j7ql194c1fbby4gy40000gn/T/ipykernel_66025/1277787668.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '3569c3de-97e3-5822-a895-d6c7d28da983' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   publications.at[row["Publication"], 'tool_id'] = uid

# %%
publications.tail()
# Out:
#                                      3D virtual reality vs. 2D desktop registration user interface comparison.  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612  GlyGen: Computational and Informatics Resource...
# f02b60a9-a6c9-51fd-9988-bc16b539826b  High-throughput discovery of novel development...
# 2e951d34-e979-5c94-a808-f43f467b7121                    H3Africa: current perspectives.
# 874e4f27-c310-51ad-a8c7-749f16baca7c  Machine Learning of Patient Characteristics to...
# 655656e6-8a48-52a1-b973-3d53768d4d04  FAIRshake: Toolkit to Evaluate the FAIRness of...
#
#                                       2021  e0258103   16    10  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612  2020     72-73   30     2
# f02b60a9-a6c9-51fd-9988-bc16b539826b  2016   508-514  537  7621
# 2e951d34-e979-5c94-a808-f43f467b7121  2018     59-66   11   NaN
# 874e4f27-c310-51ad-a8c7-749f16baca7c  2021  e2036220    4     2
# 655656e6-8a48-52a1-b973-3d53768d4d04  2019   417-421    9     5
#
#                                                                         PloS one  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612                                Glycobiology
# f02b60a9-a6c9-51fd-9988-bc16b539826b                                      Nature
# 2e951d34-e979-5c94-a808-f43f467b7121  Pharmacogenomics and personalized medicine
# 874e4f27-c310-51ad-a8c7-749f16baca7c                           JAMA network open
# 655656e6-8a48-52a1-b973-3d53768d4d04                                Cell systems
#
#                                       34705835  PMC8550408  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612  31616925  PMC7335483
# f02b60a9-a6c9-51fd-9988-bc16b539826b  27626380  PMC5295821
# 2e951d34-e979-5c94-a808-f43f467b7121  29692621  PMC5903476
# 874e4f27-c310-51ad-a8c7-749f16baca7c  33630084  PMC7907957
# 655656e6-8a48-52a1-b973-3d53768d4d04  31677972  PMC7316196
#
#                                             10.1371/journal.pone.0258103  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612               10.1093/glycob/cwz080
# f02b60a9-a6c9-51fd-9988-bc16b539826b                 10.1038/nature19356
# 2e951d34-e979-5c94-a808-f43f467b7121                10.2147/PGPM.S141546
# 874e4f27-c310-51ad-a8c7-749f16baca7c  10.1001/jamanetworkopen.2020.36220
# 655656e6-8a48-52a1-b973-3d53768d4d04          10.1016/j.cels.2019.09.011
#
#                                                Bueckle A, Buehling K, Shih PC, Borner K  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612  York WS, Mazumder R, Ranzinger R, Edwards N, K...
# f02b60a9-a6c9-51fd-9988-bc16b539826b  Dickinson ME, Flenniken AM, Ji X, Teboul L, Wo...
# 2e951d34-e979-5c94-a808-f43f467b7121  Mulder N, Abimiku A, Adebamowo SN, de Vries J,...
# 874e4f27-c310-51ad-a8c7-749f16baca7c   Amiri H, Kohane IS, Undiagnosed Diseases Network
# 655656e6-8a48-52a1-b973-3d53768d4d04  Clarke DJB, Wang L, Jones A, Wojciechowicz ML,...
#
#                                       False  \
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612   True
# f02b60a9-a6c9-51fd-9988-bc16b539826b   True
# 2e951d34-e979-5c94-a808-f43f467b7121   True
# 874e4f27-c310-51ad-a8c7-749f16baca7c   True
# 655656e6-8a48-52a1-b973-3d53768d4d04  False
#
#                                                                    tool_id
# 2337025f-3e71-50ef-850a-a37a4c7fe7ce
# 4b8567ca-3747-54f4-9023-75e352b96612                                   NaN
# f02b60a9-a6c9-51fd-9988-bc16b539826b                                   NaN
# 2e951d34-e979-5c94-a808-f43f467b7121                                   NaN
# 874e4f27-c310-51ad-a8c7-749f16baca7c                                   NaN
# 655656e6-8a48-52a1-b973-3d53768d4d04  4b13395c-45b7-5911-b255-527934471945

# %%
tools_df = pd.DataFrame(tool_list, columns=["id", "label", "description", "url", "icon"])
tools_df = tools_df.set_index("id")
tools_df
# Out:
#                                                                       label  \
# id
# 08cd40cc-f35f-547f-a8d7-524859559b0c              Playbook Workflow Builder
# 3569c3de-97e3-5822-a895-d6c7d28da983                                  GDLPA
# 4b13395c-45b7-5911-b255-527934471945                              FAIRshake
# 33ccfdb7-b5eb-5fca-9fb6-208b7b72099d                            ReproTox-KG
# b08fa45b-a979-509a-a3a5-de9616bec4e1        Data Distillery Knowledge Graph
# dcb54e80-a288-54df-9283-be888901784f  Standard RNA-seq Processing Pipelines
#
#                                                                             description  \
# id
# 08cd40cc-f35f-547f-a8d7-524859559b0c  The Common Fund Data Ecosystem (CFDE) Playbook...
# 3569c3de-97e3-5822-a895-d6c7d28da983  Gene and Drug Landing Page Aggregator (GDLPA) ...
# 4b13395c-45b7-5911-b255-527934471945  The FAIRshake toolkit was developed to enable ...
# 33ccfdb7-b5eb-5fca-9fb6-208b7b72099d  To further characterize associations between s...
# b08fa45b-a979-509a-a3a5-de9616bec4e1  The Unified Biomedical Knowledge Graph (UBKG) ...
# dcb54e80-a288-54df-9283-be888901784f  The CFDE RNA-seq Pipeline Harmonization partne...
#
#                                                                                     url  \
# id
# 08cd40cc-f35f-547f-a8d7-524859559b0c           https://playbook-workflow-builder.cloud/
# 3569c3de-97e3-5822-a895-d6c7d28da983                     https://cfde-gene-pages.cloud/
# 4b13395c-45b7-5911-b255-527934471945                           https://fairshake.cloud/
# 33ccfdb7-b5eb-5fca-9fb6-208b7b72099d                https://maayanlab.cloud/reprotox-kg
# b08fa45b-a979-509a-a3a5-de9616bec4e1  https://github.com/TaylorResearchLab/CFDE_Data...
# dcb54e80-a288-54df-9283-be888901784f  https://github.com/hubmapconsortium/salmon-rnaseq
#
#                                                            icon
# id
# 08cd40cc-f35f-547f-a8d7-524859559b0c               /img/pwb.png
# 3569c3de-97e3-5822-a895-d6c7d28da983             /img/gdlpa.png
# 4b13395c-45b7-5911-b255-527934471945         /img/fairshake.png
# 33ccfdb7-b5eb-5fca-9fb6-208b7b72099d  /img/reprotox-kg-logo.png
# b08fa45b-a979-509a-a3a5-de9616bec4e1              /img/ubkg.png
# dcb54e80-a288-54df-9283-be888901784f                        NaN

# %%
tools_df.to_csv("output/tools.tsv", sep="\t", header=None)

# %%
publications.to_csv("output/publications.tsv", sep="\t", header=None)
